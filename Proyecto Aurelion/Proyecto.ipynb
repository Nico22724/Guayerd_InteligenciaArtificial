# %% [markdown]
# <h1>Estructura</h1>
# <h3>Registros de información</h3>
#
# <h4>Clientes</h4>
# <ul>
#   <li>Id_cliente -- type:numeric</li>
#   <li>Nombre -- type:text</li>
#   <li>Email -- type:text</li>
#   <li>Ciudad -- type:text</li>
#   <li>Fecha_alta -- type:text</li>
#   <p>PK Id_cliente Tabla Ventas FK Id_cliente</p>
# </ul>
# <h4>Detalle_ventas</h4>
# <ul>
#   <li>Id_venta -- type:numeric</li>
#   <li>Id_producto -- type:numeric</li>
#   <li>Nombre_producto -- type:text</li>
#   <li>Cantidad -- type:numeric</li>
#   <li>Precio_unitario -- type:numeric</li>
#   <li>Importe -- type:numeric</li>
#   <p>PK Id_venta Tabla Ventas</p>
#   <p>FK Id_producto, Tabla Producto PK Id_producto</p>
# </ul>
# <h4>Productos</h4>
# <ul>
#   <li>Id_producto -- type:numeric</li>
#   <li>Nombre_producto -- type:text</li>
#   <li>Categoria -- type:text</li>
#   <li>Precio_unitario -- type:numeric</li>
#   <p>PK Id_producto</p>
# </ul>
# <h4>Ventas</h4>
# <ul>
#   <li>Id_venta -- type:numeric</li>
#   <li>Fecha -- type:text</li>
#   <li>Id_cliente -- type:numeric</li>
#   <li>Nombre_cliente -- type:text</li>
#   <li>Email -- type:text</li>
#   <li>Medio_pago -- type:text</li>
#   <p>PK Id_venta</p>
#   <p>FK Id_cliente Tabla Clientes PK Id_cliente</p>
# </ul>
